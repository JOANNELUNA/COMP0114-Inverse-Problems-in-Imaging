# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import radon, iradon, resize
from skimage import util
from skimage.data import shepp_logan_phantom
from scipy.sparse.linalg import LinearOperator, cg, bicgstab
import pywt

# %% [markdown]
# ### 1. Calculate the Radon transform of an image and test the back-projection method.
# (1) Load an image of the Shepp-Logan phantom of size 128 ×128. We will refer to this as $f_{true}$. Show a picture of $f_{true}$.

# %%
# Load the Shepp-Logan phantom image
f_true = resize(shepp_logan_phantom(), (128, 128), anti_aliasing=True)

# f_true = np.load('shepp_logan.npy')
# from phantominator import shepp_logan
# f_true = shepp_logan(128)

# Display the image
plt.imshow(f_true)
plt.title('Shepp-Logan Phantom Image ($f_{true}$)')
plt.axis('off')
plt.show()

# %% [markdown]
# (2) Generate the Radon transform $g= Rf$ of this phantom in 1-degree intervals from $0 −179$.
# Display $g$ as a 2D-image; this is referred to as the sinogram of $f_{true}$. What is the size of this sinogram and how is this determined

# %%
# Generate the sinogram of the image
theta = np.arange(0, 180, 1)
sinogram = radon(f_true, theta=theta, circle=True)

# Display the sinogram
plt.imshow(sinogram, extent=(0, 180, 0, sinogram.shape[0]))
plt.title('Sinogram of Shepp-Logan Phantom Image (Sinogram of $f_{true}$)')
plt.xlabel('Projection angle (degrees)')
plt.ylabel('Projection position (pixels)')
plt.show()

# Print the size of the sinogram
print('Size of sinogram:', sinogram.shape)
# Out:
# Size of sinogram: (128, 180)

# %% [markdown]
# The size of the sinogram is determined by the number of projection angles and the number of projection positions for each angle (which is the same as the length of the diagonal of the image, rounded up to the nearest integer). In this case, since the Shepp-Logan phantom has a size of $(128, 128)$, the length of the diagonal is $\sqrt{128^2 + 128^2} \approx 181$, so the sinogram has a size of $(181, 180)$. Since the radon function rounds the diagonal length up to the nearest integer, the actual number of projection positions is $182$ as shown above. The number of projection angles is $180$, since we are using 1-degree intervals from 0 to $179$ degrees.
#
# Therefore, the output sinogram has size $(182, 180)$. However, since the "circle = True" is applied in the radon function, the sinogram is cropped to a square shape, resulting in a final size of $(128, 180)$.

# %% [markdown]
# (3) Compute the unfiltered back-projection and apply it to the sinogram data you generated. What is the size of the back-projected image?

# %%
# Compute the unfiltered back-projection
back_proj = iradon(sinogram, theta=theta, circle=True, filter_name = None)

# Display the back-projected image
plt.imshow(back_proj)
plt.title('Unfiltered Back-Projection of Shepp-Logan Phantom Image')
plt.axis('off')
plt.show()

# Print the size of the back-projected image
print('Size of the back-projected reconstructed image:', back_proj.shape)
# Out:
# Size of the back-projected reconstructed image: (128, 128)

# %% [markdown]
# (4) Compute the filtered back-projection and apply it to the sinogram data $g$ that you generated. Verify that this gives a good estimate of the inverse of the Radon transform.

# %%
# Define the filters to be used
filter_types = ['ramp', 'shepp-logan', 'cosine', 'hamming', 'hann', None]

# Compute the filtered back-projections and store the MSE and PSNR values
mse_values = []
psnr_values = []
filtered_back_projs = []
for filter_type in filter_types:
    filtered_back_proj = iradon(sinogram, theta=theta, circle=True, filter_name=filter_type)
    filtered_back_projs.append(filtered_back_proj)

# Determine the number of rows and columns needed to display all the images
num_filters = len(filter_types)
num_cols = 2
num_rows = (num_filters + num_cols - 1) // num_cols

# Display the filtered back-projected images
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))
for i in range(num_filters):
    row = i // num_cols
    col = i % num_cols
    ax = axes[row][col]
    ax.imshow(filtered_back_projs[i])
    ax.set_title(f'{filter_types[i]} Filtered Back-Projection of Shepp-Logan Phantom Image')
    ax.axis('off')

    # Compute the MSE and PSNR between the filtered back-projected image and the original image
    # print('When filter type is',filter_types[i])

    mse = np.mean((filtered_back_projs[i] - f_true)**2)
    psnr = 10 * np.log10(np.max(f_true)**2 / mse)

    mse_values.append(mse)
    psnr_values.append(psnr)


plt.show()

# Plot the MSE and PSNR values for each filter type
filter_types_1 = ['ramp', 'shepp-logan', 'cosine', 'hamming', 'hann', 'None']
fig, axes = plt.subplots(2, 1, figsize=(8, 8))
axes[0].plot(filter_types_1, mse_values, 'o-')
axes[0].set_title('MSE Values for Filtered Back-Projections')
axes[0].set_xlabel('Filter Type')
axes[0].set_ylabel('MSE')

axes[1].plot(filter_types_1, psnr_values, 'o-')
axes[1].set_title('PSNR Values for Filtered Back-Projections')
axes[1].set_xlabel('Filter Type')
axes[1].set_ylabel('PSNR (dB)')

plt.tight_layout()
plt.show()
print('The small MSE indicating that the filtered back-projection is a good estimate of the original image.') 
print('The high PSNR indicating that the filtered back-projection has a high fidelity to the original image.')
# Out:
# The small MSE indicating that the filtered back-projection is a good estimate of the original image.
# The high PSNR indicating that the filtered back-projection has a high fidelity to the original image.

# %% [markdown]
# Overall, the filtered back-projection appears to be a good estimate of the inverse of the Radon transform, as evidenced by the low MSE and high PSNR values for all filter types. Also, different filter types can result in different levels of blurring and noise reduction in the reconstructed image, and the best choice of filter type for sinogram of Shepp-Logan phantom image is 'ramp'.

# %% [markdown]
# (5) Add noise to the data $g$ and test how the error in your reconstruction grows with the scale of the measurement noise

# %%
# Define the noise levels to be tested
noise_levels = np.arange(0, 1, 0.01)

# Compute the filtered back-projections for each noise level and store the MSE and PSNR values
mse_values = []
psnr_values = []
for noise_level in noise_levels:
    # Add noise to the sinogram
    noisy_sinogram = util.random_noise(sinogram, mode='gaussian', var=noise_level)

    # Compute the filtered back-projection
    filtered_back_proj = iradon(noisy_sinogram, theta=theta, circle=True, filter_name='ramp')

    # Compute the MSE and PSNR between the filtered back-projected image and the original image
    mse = np.mean((filtered_back_proj - f_true)**2)
    psnr = 10 * np.log10(np.max(f_true)**2 / mse)

    mse_values.append(mse)
    psnr_values.append(psnr)

# Plot the MSE and PSNR values for each noise level
fig, axes = plt.subplots(2, 1, figsize=(8, 8))
axes[0].plot(noise_levels, mse_values)
axes[0].set_title('MSE Values for Filtered Back-Projections with Different Noise Levels')
axes[0].set_xlabel('Noise Level (Standard Deviation)')
axes[0].set_ylabel('MSE')

axes[1].plot(noise_levels, psnr_values)
axes[1].set_title('PSNR Values for Filtered Back-Projections with Different Noise Levels')
axes[1].set_xlabel('Noise Level (Standard Deviation)')
axes[1].set_ylabel('PSNR (dB)')

plt.tight_layout()
plt.show()

# %% [markdown]
# The MSE and PSNR values are plotted against the noise level (standard deviation) as shown above. Both the MSE and PSNR values are affected by the noise level, but in different ways. The MSE measures the accuracy of the reconstruction, while the PSNR measures the fidelity of the reconstruction.
#
# As the noise level (standard deviation) increases, the trend in the MSE plot shows that the error in the reconstructed image also increases. This is because the noise corrupts the measured sinogram data, leading to inaccuracies in the reconstructed image. As the noise level increases, the sinogram data becomes increasingly noisy, leading to larger errors in the reconstruction.
#
# On the other hand, the trend in the PSNR plot shows that the fidelity of the reconstructed image decreases with increasing noise level. This is because the noise adds random variations to the reconstructed image, reducing its similarity to the true image. As the noise level increases, the difference between the reconstructed image and the true image becomes more apparent, leading to a lower PSNR value.

# %% [markdown]
# ### 2. Calculate an explicit matrix form of the Radon transform and investigate its SVD.
# You can construct an explicit matrix form of the Radon transform by calling it on an image with a single pixel of value 1 and the rest 0.
# To do this :
# * Create a zero matrix $A$ with number of rows equal to the number of angles $×$ number of projection samples, and with number of columns equal to the number of pixels in the image.
#
# * Go through a loop for the number of pixels in the image (in column-major). For each pixel $j$ in the loop create an image of the same size with a 1 in that pixel and zero everywhere else. Take the Radon transform of this image and reshape the result into a column vector. This forms the $j^th$ column of the matrix $A$.
#
# * Carry out the above steps for a manageable size of matrix, e.g. a $64 × 64$ image and only 45 projections. Take the SVD of this matrix explicitly and investigate how the SVD spectrum (the singular values) varies with
#
# (1)  Keeping the range of angles from $0 → 180$ but varying the number of projections. E.g angles = $[0:4:179]$ gives 45 projections at $4$ degree seperation.

# %%
def SVD_ProjectionNo(image_size, num_angles_list):
    # Define the number of angles and projection samples
    num_samples = image_size
    svd_spectrum = []
    for num_angles in num_angles_list:
        # Create a zero matrix with the appropriate size
        A = np.zeros((num_angles*num_samples, image_size ** 2))
        
        # Loop over each pixel in the image
        for j in range(image_size ** 2):
            # Create an image with a single pixel of value 1 at the jth position
            f = np.zeros((image_size, image_size))
            f[j // image_size, j % image_size] = 1
            
            # Take the Radon transform of the image and reshape it into a column vector
            radon_transform = radon(f, theta=np.linspace(0, 180, num_angles, endpoint=False), circle=True)
            # A[:,j] = np.reshape(radon_transform, (num_angles*num_samples,))
            # A[:, j] = radon_transform.reshape(-1)
            column = radon_transform.reshape(-1, 1)

            # Add the column to the matrix A
            A[:, j] = column.flatten() 

        # Take the SVD of the matrix A
        U, S, Vt = np.linalg.svd(A)

        # Plot the singular values
        plt.plot(S, label='Number of projections = {}'.format(num_angles))
        plt.legend()

        # Add the singular values to the list
        svd_spectrum.append(S)
        
    plt.title('SVD Spectrum vs Number of Projections')
    plt.xlabel('Singular Value Index')
    plt.ylabel('Singular Value')
    plt.show() 
    

    # Plot the singular values against the number of projections
    fig, axs = plt.subplots(4, 3, figsize=(15, 20))
    for i, spectrum in enumerate(svd_spectrum):
        row = i // 3
        col = i % 3
        axs[row, col].plot(spectrum, label=f'Number of projections = {num_angles_list[i]}')
        axs[row, col].legend()
        axs[row, col].set_xlabel('Singular Value Index')
        axs[row, col].set_ylabel('Singular Value')
    plt.show()

# %%
image_size = 64
num_angles_list = [5, 9, 12, 15, 18, 20, 30, 36, 45, 60, 90, 180]
SVD_ProjectionNo(image_size, num_angles_list)

# %% [markdown]
# The singular value decomposition (SVD) of the explicit matrix form of the Radon transform provides insights into image's properties and structure. In the case of the Radon transform. When varying the range of angles and number of projections, the amount of information available to reconstruct the image is essentially changed. The number of projections determines the amount of information about the object's geometry, while the range of angles determines the coverage of projections. As the number of projections or the range of angles is increased, more information about the object's structure is captured, resulting in a larger number of singular values in the SVD spectrum.

# %% [markdown]
# The graph above shows the distribution of singular values of the Radon transform matrix for different numbers of projections (i.e. angles) in the range 0 to 180 degrees.
#
# * As we increase the number of projections, the range of singular values increases, which indicates that there are more non-zero singular values. This is expected, as a larger number of projections means that more information is available, resulting in a higher rank and more singular values. The different endings of the lines in the plot reflect these changes in the distribution of singular values as the number of projections changes.
#
# * Additionally, we can see that as the number of projections increases, the decay rate of the singular values becomes less rapid. This means that there are more singular values contributing to the reconstruction of the image and that the reconstruction is becoming more accurate. As more projections are added, the amount of information available about the object's geometry increases. This additional information helps to reduce ambiguity in the reconstruction process, resulting in a more spread-out SVD spectrum. As a result, the spectrum becomes less sensitive to changes in the number of projections, and the frequency at which the singular values decay becomes less rapid.
#
# * Finally, we can observe that the distribution of singular values is not uniform, with a few singular values dominating the others. This indicates that the matrix has a few important features that capture most of the information about the image.

# %% [markdown]
# (2) Keeping the number of projection the same, but varying the range to being less than $0 → 180$ (i.e. limited angle). E.g. angles = $[0:1:44]$ gives 45 projections over only a 45 degree range.

# %%
def SVD_AngleRange(image_size, max_angles_list):
    # Define the number of projection samples
    num_samples = image_size
    num_angles = 45
    svd_spectrum = []
    
    for max_angles in max_angles_list:        
        # Create a zero matrix with the appropriate size
        A = np.zeros((num_angles*num_samples, image_size ** 2))
        
        # Loop over each pixel in the image
        for j in range(image_size ** 2):
            # Create an image with a single pixel of value 1 at the jth position
            f = np.zeros((image_size, image_size))
            f[j // image_size, j % image_size] = 1
            
            # Take the Radon transform of the image and reshape it into a column vector
            radon_transform = radon(f, theta=np.linspace(0, max_angles, num_angles, endpoint=False), circle=True)
            column = radon_transform.reshape(-1, 1)

            # Add the column to the matrix A
            A[:, j] = column.flatten() 

        # Take the SVD of the matrix A
        U, S, Vt = np.linalg.svd(A)

        # Plot the singular values
        plt.plot(S, label='Maximum angle = {} degrees'.format(max_angles))
        plt.legend()

        # Add the singular values to the list
        svd_spectrum.append(S)
        
    plt.title('SVD Spectrum vs Range of Angles')
    plt.xlabel('Singular Value Index')
    plt.ylabel('Singular Value')
    plt.show()

    # Plot the singular values against the number of projections
    fig, axs = plt.subplots(4, 3, figsize=(15, 20))
    for i, spectrum in enumerate(svd_spectrum):
        row = i // 3
        col = i % 3
        axs[row, col].plot(spectrum, label='Maximum angle = {} degrees'.format(max_angles))
        axs[row, col].legend()
        axs[row, col].set_xlabel('Singular Value Index')
        axs[row, col].set_ylabel('Singular Value')
    plt.show()

# %%
image_size = 64
max_angles_list = np.linspace(15, 180, 12, endpoint=True)
SVD_AngleRange(image_size, max_angles_list)

# %% [markdown]
# The graph of the SVD spectrum shows how the singular values of the Radon transform matrix vary with the range of angles used to generate the projection data.
#
# * It can be observed that all the lines in the plot end at the same point when the range of angles changes. This is in the expectation that changing the range of angles does not affect the rank of the Radon transform matrix. The rank of the matrix is determined by the number of pixels in the image, and this does not change with the range of angles.
#
# * Also, when the number of projections is fixed, increasing the range of angles results in a decrease in the frequency of the singular values which are smaller than 500, and an increase in the frequency of the singular values which are larger than 500. a reduction in ambiguity during the reconstruction process, resulting in more well-distributed singular values across the spectrum. In particular, the smaller singular values, which correspond to high-frequency information in the reconstructed image, tend to decrease in frequency because they are more sensitive to noise and errors in the measurements. On the other hand, the larger singular values, which correspond to low-frequency information in the reconstructed image, tend to increase in frequency because they are less sensitive to noise and errors in the measurements and provide more reliable information about the object's structure.
#
# * Furthermore, he frequency of the singular values dropping to zero at different singular values and at different speeds. This can be attributed to the amount of information captured by the Radon transform. As the range of angles increases, more information about the object's geometry is captured, resulting in a larger spread of singular values. The larger spread leads to a faster drop in frequency of the smaller singular values, as they capture less significant information about the object's geometry. On the other hand, the slower drop in frequency of smaller singular values for the smaller range of angles is due to the limited information captured, resulting in fewer singular values in the spectrum. The drop in frequency occurs at different singular values because the singular values correspond to the amount of information captured by each singular vector. Therefore, the amount and quality of information captured by the Radon transform affects the distribution and frequency of singular values, which in turn affects the reconstruction process.

# %% [markdown]
# ### 3. Implement a matrix-free regularised least-squares solver for the Radon Transform.
# You can find a regularised solution to the inverse Radon Transform by solving
# $$(A^TA + αL)f_{∗} = A^Tg$$
# where $A$ is the Radon transform operator, $g$ is the measured sinogram, $f_*$ is the image to be reconstructed, $L$ is the regularization matrix, and $\alpha$ is the regularization parameter. Implement the matrix-free Krylov solver will be used to solve this question.

# %%
from scipy.sparse.linalg import minres
from scipy import ndimage

def matrix_free_solver(sinogram, theta, alpha, order=0, x0=None, maxiter=100):
    """
    Solve the regularized least-squares problem using a matrix-free solver.
    
    sinogram: ndarray
        The sinogram of the image.
    theta: ndarray
        The projection angles in degrees.
    alpha: float
        The regularization parameter.
    order: int
        The order of Tikhonov regularization. Can be 0 or 1.
    x0: ndarray or None
        The initial guess for the image. If None, a zero array will be used.
    maxiter: int
        The maximum number of iterations.
    
    Returns:
    -------
    x: ndarray
        The reconstructed image.
    """
    n = sinogram.shape[0]
    # m = int(np.sqrt(2) * n)
    
    # Define the forward and adjoint operators
    def A(x):
        if x.ndim == 2:
            x_2d = x
        elif x.ndim == 1:
            x_2d = x.reshape((128,int(x.size/128)))
        return radon(x_2d, theta=theta, circle=True)#.ravel()

    def AT(x):
        if x.ndim == 2:
            x_2d = x
        elif x.ndim == 1:
            x_2d = x.reshape((128,int(x.size/128)))
        return iradon(x_2d, theta=theta, circle=True, filter_name='ramp')#.ravel()

    
    # Define the regularization operator
    if order == 0:
        def L(x):
            return alpha*np.sqrt(n)*x.ravel()
    elif order == 1:
        def L(x):
            return alpha*ndimage.laplace(x).ravel()
            # laplacian = np.zeros_like(x)
            # laplacian[1:-1, 1:-1] = x[:-2, 1:-1] - 2*x[1:-1, 1:-1] + x[2:, 1:-1] + \
            #                        x[1:-1, :-2] - 2*x[1:-1, 1:-1] + x[1:-1, 2:]
            # return alpha*laplacian.ravel()
    else:
        raise ValueError('Invalid value for order parameter.')
    
    # Define the Ax and b functions for Ax = b
    def Ax(x):
        "A - LHS of function"
        return AT(A(x)) + L(x)
    
    def b(y):
        "b - RHS of function"
        return AT(y)
    
    # Initialize the solution vector
    if x0 is None:
        x0 = np.zeros((n, n))
    x = x0.ravel()
    
    # Use the conjugate gradient method to solve the system of linear equations
    Ax_op = LinearOperator((n,n), matvec=Ax)
    print(Ax_op)
    print(b(sinogram).shape)
    print(sinogram.shape)
    x, info = cg(Ax_op, b(sinogram), x0=np.zeros((1, 1)), maxiter=maxiter, tol=1e-6, atol=0)
    # x, info = minres(Ax, b(sinogram), x0=x, maxiter=maxiter, tol=1e-6, shift=0, show=False)

    # Reshape the solution vector to an image
    x_2d = x.reshape((n, n))
    
    return x_2d

# %% [markdown]
# Compare your solution to the filtered-backprojection method for the cases, as you did in Task 2:
#
# * full range but small number of angles
# * limited angles
#
#
# Use both zero-order and first-order Tikhonov regularisation. Remember to add noise to the data.

# %%
compare_methods(image_size = f_true.shape[0], true_image = f_true, num_angles_list = [5, 9, 12, 15, 18, 20, 30, 36, 45, 60, 90, 180], max_angles_list = np.linspace(15, 180, 12, endpoint=True))
# Out:
# <128x128 _CustomLinearOperator with dtype=float64>
# (128, 128)
# (128, 5)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 compare_methods(image_size = f_true.shape[0], true_image = f_true, num_angles_list = [5, 9, 12, 15, 18, 20, 30, 36, 45, 60, 90, 180], max_angles_list = np.linspace(15, 180, 12, endpoint=True))
#
# Cell In[109], line 18, in compare_methods(image_size, true_image, num_angles_list, max_angles_list)
#      15 fbps_image = iradon(noisy_sinogram, theta=np.linspace(0, 180, num_angles, endpoint=False), circle=True, filter_name='ramp')
#      17 # Reconstruct using matrix-free Krylov solver with 0th order Tikhonov regularization
# ---> 18 tikhonov_0th_image = matrix_free_solver(noisy_sinogram, theta=np.linspace(0, 180, num_angles, endpoint=False), alpha=1e-5, order=0, maxiter=500)
# ...

# %%
def compare_methods(image_size, true_image, num_angles_list, max_angles_list):
    fbps_rmse_list = []
    tikhonov_0th_rmse_list = []
    tikhonov_1st_rmse_list = []
    
    for num_angles in num_angles_list:
        # Generate sinogram from true image
        sinogram = radon(true_image, theta=np.linspace(0, 180, num_angles, endpoint=False), circle=True)

        # Add noise to the sinogram
        noise = np.random.normal(0, 0.1, sinogram.shape)
        noisy_sinogram = sinogram + noise

        # Compute the filtered back-projections
        fbps_image = iradon(noisy_sinogram, theta=np.linspace(0, 180, num_angles, endpoint=False), circle=True, filter_name='ramp')

        # Reconstruct using matrix-free Krylov solver with 0th order Tikhonov regularization
        tikhonov_0th_image = matrix_free_solver(noisy_sinogram, theta=np.linspace(0, 180, num_angles, endpoint=False), alpha=1e-5, order=0, maxiter=500)

        # Reconstruct using matrix-free Krylov solver with 1st order Tikhonov regularization
        tikhonov_1st_image = matrix_free_solver(noisy_sinogram, theta=np.linspace(0, 180, num_angles, endpoint=False), alpha=1e-5, order=1, maxiter=500)

        # Calculate RMSE for each method
        fbps_rmse =  np.sqrt(np.mean((fbps_image - true_image)**2))
        tikhonov_0th_rmse = np.sqrt(np.mean((tikhonov_0th_image - true_image)**2))
        tikhonov_1st_rmse = np.sqrt(np.mean((tikhonov_1st_image - true_image)**2))

        # Add RMSE to lists
        fbps_rmse_list.append(fbps_rmse)
        tikhonov_0th_rmse_list.append(tikhonov_0th_rmse)
        tikhonov_1st_rmse_list.append(tikhonov_1st_rmse)

        # Plot the images for comparison
        fig, axs = plt.subplots(1, 3, figsize=(10, 6))
        axs[0].imshow(fbps_image)
        axs[0].set_title('FBP, Number of Projections = {}'.format(num_angles))
        axs[1].imshow(tikhonov_0th_image)
        axs[1].set_title('Tikhonov 0th Order, Number of Projectionse = {}'.format(num_angles))
        axs[2].imshow(tikhonov_1st_image)
        axs[2].set_title('Tikhonov 1st Order, Number of Projections = {}'.format(num_angles))
        plt.show()
        
    # Plot the results for varying number of projections
    plt.figure(figsize=(10, 6))
    plt.plot(num_projections_list, fbps_rmse_list, label='FBP')
    plt.plot(num_projections_list, tikhonov_0th_rmse_list, label='Tikhonov 0th Order')
    plt.plot(num_projections_list, tikhonov_1st_rmse_list, label='Tikhonov 1st Order')
    plt.legend()
    plt.title('RMSE vs Number of Projections')
    plt.xlabel('Number of Projections')
    plt.ylabel('RMSE')
    plt.show()
    
    for max_angle in max_angles_list:
        # Generate sinogram from true image
        sinogram = radon(true_image, theta=np.linspace(0, max_angle, 45, endpoint=False), circle=True)

        # Add noise to the sinogram
        noise = np.random.normal(0, 0.1, sinogram.shape)
        noisy_sinogram = sinogram + noise

        # Reconstruct using FBP
        fbps_image = iradon(noisy_sinogram, theta=np.linspace(0, max_angle, 45, endpoint=False), circle=True, filter_name='ramp')

        # Reconstruct using matrix-free Krylov solver with 0th order Tikhonov regularization
        tikhonov_0th_image = matrix_free_solver(noisy_sinogram, theta=np.linspace(0, max_angle, 45, endpoint=False), alpha=1e-5, order=0, maxiter=500)

        # Reconstruct using matrix-free Krylov solver with 1st order Tikhonov regularization
        tikhonov_1st_image = matrix_free_solver(noisy_sinogram, theta=np.linspace(0, max_angle, 45, endpoint=False), alpha=1e-5, order=1, maxiter=500)

        # Calculate RMSE for each method
        fbps_rmse =  np.sqrt(np.mean((fbps_image - true_image)**2))
        tikhonov_0th_rmse = np.sqrt(np.mean((tikhonov_0th_image - true_image)**2))
        tikhonov_1st_rmse = np.sqrt(np.mean((tikhonov_1st_image - true_image)**2))

        # Plot the images for comparison
        fig, axs = plt.subplots(1, 3, figsize=(10, 6))
        axs[0].imshow(fbps_image)
        axs[0].set_title('FBP, Max Angle = {}'.format(max_angle))
        axs[1].imshow(tikhonov_0th_image)
        axs[1].set_title('Tikhonov 0th Order, Max Angle = {}'.format(max_angle))
        axs[2].imshow(tikhonov_1st_image)
        axs[2].set_title('Tikhonov 1st Order, Max Angle = {}'.format(max_angle))
        plt.show()

        # Add RMSE to lists
        fbps_rmse_list.append(fbps_rmse)
        tikhonov_0th_rmse_list.append(tikhonov_0th_rmse)
        tikhonov_1st_rmse_list.append(tikhonov_1st_rmse)

    # Plot the results for varying max angles
    plt.figure(figsize=(10, 6))
    plt.plot(max_angles_list, fbps_rmse_list, label='FBP')
    plt.plot(max_angles_list, tikhonov_0th_rmse_list, label='Tikhonov 0th Order')
    plt.plot(max_angles_list, tikhonov_1st_rmse_list, label='Tikhonov 1st Order')
    plt.legend()
    plt.title('RMSE vs Maximum Angle')
    plt.xlabel('Maximum Angle')
    plt.ylabel('RMSE')
    plt.show()

# %% [markdown]
# ### 4. Write a Haar wavelet denoiser.
# In this task you will perform denoising using a wavelet transform and shrinkage of the wavelet coefficients.
#
# (1) Take any (monochrome) image of your choice. Calculate the Haar wavelet transform of this image. Plot some of the coefficients and explain what you see.

# %%
# Calculate Haar wavelet coefficients
coeffs = pywt.dwt2(f_true, 'haar')

# Plot wavelet coefficients
plt.figure(figsize=(10, 10))
plt.subplot(221)
plt.imshow(coeffs[0])
plt.title('Approximation coefficients')
plt.subplot(222)
plt.imshow(coeffs[1][0])
plt.title('Horizontal detail coefficients')
plt.subplot(223)
plt.imshow(coeffs[1][1])
plt.title('Vertical detail coefficients')
plt.subplot(224)
plt.imshow(coeffs[1][2])
plt.title('Diagonal detail coefficients')
plt.show()

# %% [markdown]
# (2) Reconstruct the image from the coefficients by calling the inverse wavelet transform. Check if your reconstructed image coincides with the original.

# %%
# Reconstruct image from wavelet coefficients
reconstructed_image = pywt.idwt2(coeffs, 'haar')

# Compare original and reconstructed images
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.imshow(f_true)
plt.title('Original Image')
plt.subplot(122)
plt.imshow(reconstructed_image)
plt.title('Reconstructed Image')
plt.show()

# %% [markdown]
# (3) Write a function that implements thresholding for a given range (the different scales of your wavelet coefficients) and threshold parameter, and form a modified image by performing the inverse wavelet transform on the thresholded coefficients.

# %%
def threshold(wave_coeffs, threshold_val, threshold_range):
    """
    Apply thresholding to the wavelet coefficients.

    Args:
    wave_coeffs: 2D numpy array, containing wavelet coefficients
    threshold_val: float, the threshold value for hard thresholding
    threshold_range: list of integers, indicating the scales to threshold

    Returns:
    2D numpy array, modified wavelet coefficients
    """
    # Copy the input wavelet coefficients
    modified_coeffs = wave_coeffs.copy()

    # Loop through each scale in threshold range
    for scale in threshold_range:
        # Apply hard thresholding to the detail coefficients
        modified_coeffs[1][scale][abs(modified_coeffs[1][scale]) < threshold_val] = 0
    
    return modified_coeffs

# %% [markdown]
# (4) Create a noisy version of your original image and perform denoising by thresholding of the wavelet coefficients. Investigate the effect of changing the range and the threshold parameter.

# %%
def denoise_wavelet(image, threshold_val, threshold_range):
    """
    Denoise image using wavelet thresholding.

    Args:
    image: 2D numpy array, containing the original image
    threshold_val: float, the threshold value for hard thresholding
    threshold_range: list of integers, indicating the scales to threshold

    Returns:
    2D numpy array, denoised image
    """
    # Calculate the wavelet transform of the image
    wave_coeffs = pywt.wavedec2(image, 'haar', level=3)

    # Apply thresholding to the wavelet coefficients
    modified_coeffs = threshold(wave_coeffs, threshold_val, threshold_range)

    # Reconstruct the image using the modified wavelet coefficients
    denoised_image = pywt.waverec2(modified_coeffs, 'haar')

    return denoised_image

# %%
# Create a noisy version of the original image
noisy_image = add_gaussian_noise(true_image, 0.1)

# Define threshold ranges and threshold values to try
threshold_ranges = [[1], [1, 2], [1, 2, 3]]
threshold_values = [0.05, 0.1, 0.2]

# Loop through all combinations of threshold range and value
for threshold_range in threshold_ranges:
    for threshold_val in threshold_values:
        # Perform denoising using wavelet thresholding
        denoised_image = denoise_wavelet(noisy_image, threshold_val, threshold_range)

        # Calculate the RMSE between the denoised image and the original image
        rmse = np.sqrt(np.mean((denoised_image - true_image)**2))

        # Print the results
        print(f'Threshold Range: {threshold_range}, Threshold Value: {threshold_val:.2f}, RMSE: {rmse:.4f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 2
#       1 # Create a noisy version of the original image
# ----> 2 noisy_image = add_gaussian_noise(true_image, 0.1)
#       4 # Define threshold ranges and threshold values to try
#       5 threshold_ranges = [[1], [1, 2], [1, 2, 3]]
#
# NameError: name 'add_gaussian_noise' is not defined

# %% [markdown]
# ## 5. Iterative soft-thresholding for X-ray tomography.
#
# The aim of this exercise is to write your own sparsity promoting reconstruction algorithm for
# X-ray tomography, by solving
# $$\frac{1}{2}||Af − g||^2_2 + α||Wf||_1 → min$$
# where $W$ denotes the wavelet transform. To achieve this we use iterative soft-thresholding with Haar wavelets.
#
# You need to implement an iterative algorithm that performs the update equation:
# $$f_{k+1} = S_{α,W}(f_k − λA^T(Af_k − g))$$
#
# Here $S_{α,W}$ is the soft-thresholding operator given in lectures,
# $$S_{α,W}(f) = W^{-1}S_{\mu}Wf$$
#
# This process is equivalent to the denoiser from Task 4, where $S_µ$ is given by your threshold function with threshold parameter $µ = αλ$ as discussed in the lecture.
#
# In order to have a full algorithm you need consider the following points:
# 1. Define an initial iterate $f_0$

# %% [markdown]
# 2. What is a good stopping criterion for your algorithm?

# %% [markdown]
# 3. You need to choose a stable step size λ: Start with a small value $λ << 1$ and make sure that the reconstruction gets better each step. Increase it gradually to converge faster.

# %% [markdown]
# 4. Can we include more prior knowledge, like non-negativity?

# %% [markdown]
# 5. Evaluate your algorithm for varying noise levels and projection geometries (low number of angles/limited angle).
